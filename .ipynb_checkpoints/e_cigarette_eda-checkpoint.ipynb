# %% [markdown]
# ## Team Beta Exploratory Data Analysis
# #### Elizabeth Greenan, Nick Perry, Kevin Wilson

# %%
import pandas as pd

# %%
e_cig_data = pd.read_csv("data/LLCP2024.csv")
e_cig_data.head()
# Out:
#    _STATE  FMONTH    IDATE  IMONTH  IDAY  IYEAR  DISPCODE       SEQNO  \
# 0       1       2  2282024     2.0  28.0   2024      1100  2024000001
# 1       1       2  2212024     2.0  21.0   2024      1100  2024000002
# 2       1       2  2212024     2.0  21.0   2024      1100  2024000003
# 3       1       2  2282024     2.0  28.0   2024      1100  2024000004
# 4       1       2  2212024     2.0  21.0   2024      1100  2024000005
#
#          _PSU  CTELENM1  ...  _LCSCTSN  _LCSPSTF  DRNKANY6  DROCDY4_  \
# 0  2024000001       1.0  ...       NaN       9.0         2       0.0
# 1  2024000002       1.0  ...       4.0       9.0         2       0.0
# 2  2024000003       1.0  ...       4.0       2.0         1     100.0
# 3  2024000004       1.0  ...       NaN       9.0         2       0.0
# 4  2024000005       1.0  ...       3.0       9.0         2       0.0
#
#    _RFBING6  _DRNKWK3  _RFDRHV9  _FLSHOT7  _PNEUMO3  _AIDTST4
# 0         1         0         1       1.0       2.0       2.0
# ...

# %%
e_cig_data.shape
# Out:
# (457670, 301)

# %%
e_cig_data.describe()
# Out:
#               _STATE         FMONTH         IDATE         IMONTH  \
# count  457670.000000  457670.000000  4.576700e+05  457669.000000
# mean       30.823537       6.426995  6.801723e+06       6.644815
# std        15.939364       3.356938  3.316166e+06       3.316101
# min         1.000000       1.000000  2.024000e+03       1.000000
# 25%        18.000000       4.000000  4.112024e+06       4.000000
# 50%        31.000000       7.000000  7.052024e+06       7.000000
# 75%        44.000000       9.000000  9.302024e+06       9.000000
# max        78.000000      12.000000  1.231202e+07      12.000000
#
#                 IDAY          IYEAR       DISPCODE         SEQNO  \
# count  457669.000000  457670.000000  457670.000000  4.576700e+05
# mean       15.489804    2024.042723    1118.669784  2.024007e+09
# std         8.664519       0.202232      38.966920  7.488291e+03
# min         1.000000    2024.000000    1100.000000  2.024000e+09
# ...

# %%
e_cig_data["IYEAR"].unique()
# Out:
# array([2024, 2025])

# %%
e_cig_data["IYEAR"].value_counts()
# Out:
# IYEAR
# 2024    438117
# 2025     19553
# Name: count, dtype: int64

# %% [markdown]
# Create a list of the variables we want to keep (these are coming directly from the Data Dictionary)

# %%
intitial_cig_data_variables = ["_AGEG5YR", "ALCDAY4", "AVEDRNK4", "_BMI5", "_BMI5CAT", "CHECKUP1", "CHILDREN", "_CURECI3", "CVDCRHD4", "_DENVST3", "DIABETE4", "ECIGNOW3", "EDUCA", "EMTSUPRT", "EXERANY2", "GENHLTH", "_HLTHPL2", "INCOME3", "LASTSMK2", "_LCSAGE", "_LCSCTSN", "LCSLAST_", "LCSNUMC_", "_LCSYSMK", "_LCSSMKG", "_LCSYQTS", "LSATISFY", "MARIJAN1", "MARITAL", "MEDCOST1", "MENTCIGS", "MENTECIG", "_MENT14D", "MENTHLTH", "_PACKDAY", "_PACKYRS", "_PHYS14D", "PHYSHLTH", "POORHLTH", "PREDIAB2", "_RACE", "_RFBMI5", "_RFHLTH", "_RFSMOK3", "SEXVAR", "SDLONELY", "SMOKE100", "SMOKDAY2", "_SMOKER3", "SSBSUGR2", "SSBFRUT3", "STOPSMK2", "_TOTINDA", "USENOW3"]

# %%
filtered_e_cig_data = e_cig_data[intitial_cig_data_variables]

# %%
filtered_e_cig_data.head()
# Out:
#    _AGEG5YR  ALCDAY4  AVEDRNK4   _BMI5  _BMI5CAT  CHECKUP1  CHILDREN  \
# 0        12    888.0       NaN  2249.0       2.0       1.0      88.0
# 1        13    888.0       NaN  2583.0       3.0       1.0      88.0
# 2         8    230.0       2.0  2253.0       2.0       4.0      88.0
# 3        13    888.0       NaN  2509.0       3.0       1.0      88.0
# 4         6    888.0       NaN  1977.0       2.0       1.0      88.0
#
#    _CURECI3  CVDCRHD4  _DENVST3  ...  SEXVAR  SDLONELY  SMOKE100  SMOKDAY2  \
# 0         1       2.0         1  ...       2       5.0       2.0       NaN
# 1         1       1.0         1  ...       1       5.0       1.0       3.0
# 2         1       2.0         2  ...       1       5.0       1.0       1.0
# 3         1       2.0         1  ...       1       5.0       2.0       NaN
# 4         1       2.0         1  ...       1       1.0       2.0       NaN
#
#    _SMOKER3  SSBSUGR2  SSBFRUT3  STOPSMK2  _TOTINDA  USENOW3
# ...

# %%
filtered_e_cig_data.shape
# Out:
# (457670, 54)

# %% [markdown]
# Export condensed dataset to a CSV file

# %%
filtered_e_cig_data.to_csv('initial_variables.csv', index = False)
